# %%
# %conda install -c conda-forge yfinance
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - conda-forge
#  - defaults
#  - pytorch
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/erdos_may_2024
#
#   added / updated specs:
#     - yfinance
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     appdirs-1.4.4              |     pyh9f0ad1d_0          13 KB  conda-forge
#     ca-certificates-2024.6.2   |       hf0a4a13_0         153 KB  conda-forge
#     certifi-2024.6.2           |     pyhd8ed1ab_0         157 KB  conda-forge
#     frozendict-2.4.4           |  py311hd3f4193_0          31 KB  conda-forge
#     html5lib-1.1               |     pyh9f0ad1d_0          89 KB  conda-forge
#     libxslt-1.1.39             |       h223e5b9_0         220 KB  conda-forge
#     lxml-5.2.2                 |  py311hf9a6a72_0         1.1 MB  conda-forge
#     multitasking-0.0.9         |     pyhd8ed1ab_0          12 KB  conda-forge
#     openssl-3.3.1              |       hfb2fe0b_1         2.8 MB  conda-forge
#     peewee-3.17.3              |  py311haea84a1_0         470 KB  conda-forge
#     yfinance-0.2.40            |     pyhd8ed1ab_0          64 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         5.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   appdirs            conda-forge/noarch::appdirs-1.4.4-pyh9f0ad1d_0
#   frozendict         conda-forge/osx-arm64::frozendict-2.4.4-py311hd3f4193_0
#   html5lib           conda-forge/noarch::html5lib-1.1-pyh9f0ad1d_0
#   libxslt            conda-forge/osx-arm64::libxslt-1.1.39-h223e5b9_0
#   lxml               conda-forge/osx-arm64::lxml-5.2.2-py311hf9a6a72_0
#   multitasking       conda-forge/noarch::multitasking-0.0.9-pyhd8ed1ab_0
#   peewee             conda-forge/osx-arm64::peewee-3.17.3-py311haea84a1_0
#   yfinance           conda-forge/noarch::yfinance-0.2.40-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2024.3.11-~ --> conda-forge::ca-certificates-2024.6.2-hf0a4a13_0
#   openssl                                  3.3.0-h0d3ecfb_0 --> 3.3.1-hfb2fe0b_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            pkgs/main/osx-arm64::certifi-2024.6.2~ --> conda-forge/noarch::certifi-2024.6.2-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages:
# openssl-3.3.1        | 2.8 MB    |                                       |   0%
# lxml-5.2.2           | 1.1 MB    |                                       |   0%
#
# peewee-3.17.3        | 470 KB    |                                       |   0%
#
#
# libxslt-1.1.39       | 220 KB    |                                       |   0%
#
#
#
# certifi-2024.6.2     | 157 KB    |                                       |   0%
#
#
#
#
# ca-certificates-2024 | 153 KB    |                                       |   0%
#
#
#
#
#
# html5lib-1.1         | 89 KB     |                                       |   0%
#
#
#
#
#
#
# yfinance-0.2.40      | 64 KB     |                                       |   0%
#
#
#
#
#
#
#
# frozendict-2.4.4     | 31 KB     |                                       |   0%
#
#
#
#
#
#
#
#
# appdirs-1.4.4        | 13 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
# multitasking-0.0.9   | 12 KB     |                                       |   0%
# openssl-3.3.1        | 2.8 MB    | 2                                     |   1%
#
# peewee-3.17.3        | 470 KB    | #2                                    |   3%
#
#
#
# certifi-2024.6.2     | 157 KB    | ###7                                  |  10%
#
#
# libxslt-1.1.39       | 220 KB    | ##6                                   |   7%
#
#
#
# openssl-3.3.1        | 2.8 MB    | ########################              |  65%
#
#
#
#
#
# html5lib-1.1         | 89 KB     | ######6                               |  18%
#
#
#
#
# ca-certificates-2024 | 153 KB    | ###8                                  |  10%
#
# peewee-3.17.3        | 470 KB    | ##################################### | 100%
#
# peewee-3.17.3        | 470 KB    | ##################################### | 100%
#
#
# libxslt-1.1.39       | 220 KB    | ##################################### | 100%
#
#
# libxslt-1.1.39       | 220 KB    | ##################################### | 100%
#
#
#
#
#
#
# yfinance-0.2.40      | 64 KB     | #########3                            |  25%
#
#
#
#
#
#
#
# frozendict-2.4.4     | 31 KB     | ###################                   |  52%
# lxml-5.2.2           | 1.1 MB    | ##################################### | 100%
# lxml-5.2.2           | 1.1 MB    | ##################################### | 100%
#
#
#
#
# ca-certificates-2024 | 153 KB    | ##################################### | 100%
#
#
#
#
#
# html5lib-1.1         | 89 KB     | ##################################### | 100%
#
#
#
#
#
#
# yfinance-0.2.40      | 64 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# frozendict-2.4.4     | 31 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# multitasking-0.0.9   | 12 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# openssl-3.3.1        | 2.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# appdirs-1.4.4        | 13 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: / WARNING conda.core.path_actions:verify(1055): Unable to create environments file. Path not writable.
#   environment location: /Users/arvindsuresh/.conda/environments.txt
#
# done
# Executing transaction: | WARNING conda.core.envs_manager:register_env(66): Unable to register environment. Path not writable or missing.
#   environment location: /opt/anaconda3/envs/erdos_may_2024
#   registry file: /Users/arvindsuresh/.conda/environments.txt
# done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
#check if yfinance is installed
import yfinance as yf

# %%
#check yfinance version
yf.__version__
# Out:
# '0.2.40'
