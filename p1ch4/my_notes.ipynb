# %%
#use conda to install pytorch and torchvision
# %conda install -c pytorch pytorch torchvision
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - pytorch
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/erdos_may_2024
#
#   added / updated specs:
#     - pytorch
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2024.6.2           |  py311hca03da5_0         162 KB
#     libblas-3.9.0              |1_h9886b1c_netlib         156 KB
#     libcblas-3.9.0             |1_h9886b1c_netlib          43 KB
#     liblapack-3.9.0            |1_h9886b1c_netlib         2.2 MB
#     libxgboost-2.0.3           |       h313beb8_0         2.8 MB
#     networkx-3.2.1             |  py311hca03da5_0         3.0 MB
#     pytorch-2.3.1              |         py3.11_0        56.6 MB  pytorch
#     scikit-learn-1.4.2         |  py311h7aedaa7_1         9.5 MB
# ...

# %%
import torch
print(torch.__version__)
# Out:
# 2.3.1
